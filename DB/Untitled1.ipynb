# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
m_top1 =[1,19,58,111,69,61,49,66,56]
sum(m_top1)
# Out:
# 490

# %%
MDS=[20,40,60,80,100,120,140,160,180]


# m_top1 =[8,75,98,118,62,51,39,20,19]

m_top1 =[1,32,58,198,62,51,39,20,19]
m_top5 =[11,129,199,64,25,28,15,12,7]
# top10 =[13,131,218,61,20,23,9,7,8]

x_top1 =[17,48,67,71,28,16,8,5,0]
x_top5 =[22,59,72,64,25,9,5,4,0]

l_top1 =[18,24,15,7,2,0,0,0,0]
l_top5 =[19,32,10,3,2,0,0,0,0]


x=MDS

plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False


plt.subplot(212)
plt.grid(True)
plt.ylim((0,200))
plt.plot(x,m_top1,label='TOP 1')
plt.plot(x,m_top5,color='red',linestyle='--',label='TOP 5')
plt.legend(loc='best')
plt.ylabel('对应MDR下的模型预测数')
plt.xlabel('最小定位误差 MDR')
plt.title('建筑物密集区')

plt.subplot(222)
plt.grid(True)
plt.ylim((0,200))
plt.plot(x,x_top1,label='TOP 1')
plt.plot(x,x_top5,color='red',linestyle='--',label='TOP 5')
plt.legend(loc='best')
plt.ylabel('对应MDR下的模型预测数')
plt.xlabel('最小定位误差 MDR')
plt.title('建筑物稀疏区')

plt.subplot(221)
plt.grid(True)
plt.ylim((0,200))
plt.plot(x,l_top1,label='TOP 1')
plt.plot(x,l_top5,color='red',linestyle='--',label='TOP 5')
plt.legend(loc='best')
plt.ylabel('对应MDR下的模型预测数')
plt.xlabel('最小定位误差 MDR')
plt.title('绿地区')

plt.show()

# %%
m_top1 =[8,75,128,138,42,41,24,15,19]
sum(m_top5)
# Out:
# 490

# %%
plt.subplot(211)
plt.grid(True)
plt.ylim((0,200))
plt.plot(x,m_top1,label='多目标定位')
plt.plot(x,m_top5,color='red',linestyle='--',label='排序模型定位')
plt.legend(loc='best')
plt.ylabel('对应MDR下的模型预测数')
plt.xlabel('最小定位误差 MDR')
plt.title('建筑物密集区')

plt.subplot(212)
plt.grid(True)
plt.hist(func(m_top1),label="多目标定位",density=True,cumulative=True,histtype='bar',alpha=0.5)
plt.hist(func(m_top5),label="排序模型定位",density=True,cumulative=True,histtype='bar', color="g",alpha=0.5)
plt.xlabel('最小定位误差MDR')
plt.ylabel('对应MDR下的模型预测占比')
plt.legend()

# %%
MDS=[20,40,60,80,100,120,140,160,180]

m_top1 =[8,75,128,138,42,41,24,15,19]


xx = []

# %%
sum(m_top5)
# Out:
# 490

# %%
a=[]
a.append(boxWeight)
a
# Out:
# [array([ 2, 11, 11,  3,  3,  2,  5,  2,  3,  3, 10, 10,  9,  2,  8,  3,  9,
#          8,  9, 10,  6,  5, 10,  8,  9,  4,  3,  4,  2,  2,  3,  5,  6,  2,
#          8,  4, 11, 11,  9,  7,  9,  6,  2,  3,  4, 11,  2,  4,  9,  7, 11,
#          7,  5,  2,  8, 10, 11,  4,  4,  6,  9,  6,  6,  8,  5,  5,  3,  7,
#          3,  8,  8,  3,  2,  4, 10,  9,  8, 11, 11,  5,  9,  5,  9,  3,  3,
#          6,  5,  3,  5, 10,  7,  7,  5,  8,  9,  3,  7,  9, 11,  6])]

# %%
def func(arr):
    newArr = []
    for i in range(0,9):
        down = 5
        up = 0
        if i!=0:
            down = MDS[i-1]
        up = MDS[i]
        tmp = np.random.randint(down, up, arr[i]).tolist()
        newArr=newArr+tmp
    return newArr

# %%
a=func(m_top1)
len(a)
# Out:
# 490

# %%
x = [1,5,10,15]
y1 = [78.638215,59.693025,51.592124,47.857239]
y2 = [92.567814,85.319841,81.236181,75.426732]


y11 = [61.289479,47.674921,45.375931,43.384612]
y21 = [67.402198,61.612901,56.528910,51.236141]

y12 = [32.532755,27.561946,21.789619,20.562124]
y22 = [31.410294,26.567839,23.567186,20.519461]

plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False



plt.subplot(212)
plt.grid(True)
plt.ylim((10,100))
plt.plot(x,y1,label='排序模型定位')
plt.plot(x,y2,color='red',linestyle='--',label='多目标定位')
plt.legend(loc='best')
plt.ylabel('平均最小定位误差 AMDR')
plt.xlabel('候选栅格 TOP K')
plt.title('建筑物密集区')

plt.subplot(222)
plt.grid(True)
plt.ylim((10,100))
plt.plot(x,y11,label='排序模型定位')
plt.plot(x,y21,color='red',linestyle='--',label='多目标定位')
plt.legend(loc='best')
plt.title('建筑物稀疏区')

plt.subplot(221)
plt.grid(True)
plt.ylim((0,100))
plt.plot(x,y12,label='排序模型定位')
plt.plot(x,y22,color='red',linestyle='--',label='多目标定位')
plt.legend(loc='best')
plt.ylabel('平均最小定位误差 AMDR')

plt.title('绿地区')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-cd7837893aa7> in <module>()
#      18 plt.grid(True)
#      19 plt.ylim((10,100))
# ---> 20 plt.plot(x,y1,label='排序模型定位',cumulative=True)
#      21 plt.plot(x,y2,color='red',linestyle='--',label='多目标定位')
#      22 plt.legend(loc='best')
#
# D:\Anaconda\envs\deep_learning\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3361                       mplDeprecation)
#    3362     try:
# -> 3363         ret = ax.plot(*args, **kwargs)
#    3364     finally:
#    3365         ax._hold = washold
#
# D:\Anaconda\envs\deep_learning\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# ...
